# %%
from p3_ import PolicyIteration
import time

# %%
pi = PolicyIteration()

# %% [markdown]
# # Checking 3(a)

# %%
pi.gw.S[0]
# Out:
# (0, 0, 0)

# %%
pi.policy[0]
# Out:
# ['forward', 'right']

# %%
print(pi.gw.S[300])
print(pi.policy[300])
# Out:
# (4, 1, 0)
# ['forward', 'right']

# %%
print(pi.gw.S[231])
print(pi.policy[231])
# Out:
# (3, 1, 3)
# ['forward', 'right']

# %% [markdown]
# # Testing out 3(b) by doing 3(c)

# %%
s = [1,4,6]
pi.plot_trajectory(s)
# Out:
# (array([126]),)
# (array([139]),)
# (array([128]),)
# (array([200]),)

# %%
s = [1,4,7]
pi.plot_trajectory(s)
# Out:
# (array([127]),)
# (array([140]),)
# (array([211]),)
# (array([200]),)

# %%
s = [0,0,0]
pi.plot_trajectory(s)
# Out:
# (array([0]),)
# (array([13]),)
# (array([26]),)
# (array([97]),)
# (array([110]),)
# (array([181]),)
# (array([194]),)

# %% [markdown]
# # 3E

# %%
V = pi.policy_evaluation(discount=0.9)

# %%
import numpy as np

# %%
s = [1,4,6]
s_index = np.where((np.array(pi.gw.S) == s).all(axis=1))

# %%
print('Value is ', V[s_index[0][0]])
# Out:
# ('Value is ', -90.72994046108698)

# %% [markdown]
# # 3H

# %%
start_time = time.time()
pi.solve_optimal_policy(discount = 0.9)
print("--- %s seconds ---" % (time.time() - start_time))
pi.plot_trajectory([1,4,6])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [[ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True  True]
#  [ True  True]
#  [ True  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True  True]
#  [False  True]
#  [ True  True]
#  [False False]
#  [False  True]
#  [False False]
#  [ True  True]
#  [False  True]
#  [ True  True]
#  [False False]
#  [False  True]
#  [False False]
#  [ True  True]
#  [ True  True]
#  [False  True]
#  [False False]
#  [False False]
#  [False False]
#  [False  True]
#  [ True  True]
#  [False  True]
#  [False False]
#  [False False]
# ...

# %%
pi.T
# Out:
# {0: [[['forward', 'right'], [[0, 1, 1, 1.0]]],
#   [['forward', 'left'], [[0, 1, 11, 1.0]]],
#   [['backward', 'right'], [[0, 0, 1, 1.0]]],
#   [['backward', 'left'], [[0, 0, 11, 1.0]]],
#   [['forward', 'no rotation'], [[0, 1, 0, 1.0]]],
#   [['backward', 'no rotation'], [[0, 0, 0, 1.0]]],
#   [['no action', ''], [0, 0, 0, 1]]],
#  1: [[['forward', 'right'], [[0, 1, 2, 1.0]]],
#   [['forward', 'left'], [[0, 1, 0, 1.0]]],
#   [['backward', 'right'], [[0, 0, 2, 1.0]]],
#   [['backward', 'left'], [[0, 0, 0, 1.0]]],
#   [['forward', 'no rotation'], [[0, 1, 1, 1.0]]],
#   [['backward', 'no rotation'], [[0, 0, 1, 1.0]]],
#   [['no action', ''], [0, 0, 1, 1]]],
#  2: [[['forward', 'right'], [[1, 0, 3, 1.0]]],
#   [['forward', 'left'], [[1, 0, 1, 1.0]]],
#   [['backward', 'right'], [[0, 0, 3, 1.0]]],
#   [['backward', 'left'], [[0, 0, 1, 1.0]]],
#   [['forward', 'no rotation'], [[1, 0, 2, 1.0]]],
#   [['backward', 'no rotation'], [[0, 0, 2, 1.0]]],
#   [['no action', ''], [0, 0, 2, 1]]],
# ...

# %%
len(pi.policy)
# Out:
# 432

# %%
start_time = time.time()
V = pi.policy_evaluation(discount= 0.9)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 2.63800001144 seconds ---

# %%
np.array_equal(pi.past_policy, pi.policy)
# Out:
# False

# %%
import numpy as np

# %%
pi.policy
# Out:
# [['backward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'left'],
#  ['forward', 'left'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['forward', 'no rotation'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
#  ['backward', 'no rotation'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'left'],
#  ['forward', 'right'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
# ...

# %%
pi.past_policy
# Out:
# [['backward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['backward', 'right'],
#  ['forward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'left'],
#  ['forward', 'left'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['forward', 'left'],
#  ['forward', 'no rotation'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
#  ['backward', 'no rotation'],
#  ['backward', 'right'],
#  ['forward', 'right'],
#  ['forward', 'left'],
#  ['forward', 'right'],
#  ['forward', 'right'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'left'],
#  ['backward', 'right'],
#  ['backward', 'right'],
# ...

# %%
pi.past_policy == pi.policy
# Out:
# True

# %%
x = [['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['no action', ''], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['no action', ''], ['forward', 'no rotation'], ['forward', 'no rotation'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'no rotation'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'no rotation'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['no action', ''], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left']]

# %%
x = np.array(x)

# %%
x0 = [['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['no action', ''], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['no action', ''], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'no rotation'], ['forward', 'no rotation'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'right'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'left'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'left'], ['forward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'no rotation'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'no rotation'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'right'], ['no action', ''], ['backward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'right'], ['no action', ''], ['forward', 'left'], ['backward', 'no rotation'], ['backward', 'right'], ['backward', 'left'], ['backward', 'left'], ['backward', 'left'], ['no action', ''], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'left'], ['no action', ''], ['backward', 'right'], ['backward', 'left'], ['backward', 'left'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'right'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'no rotation'], ['forward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'left'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'left'], ['forward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'no rotation'], ['backward', 'left'], ['backward', 'left'], ['backward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'no rotation'], ['forward', 'left'], ['forward', 'left'], ['backward', 'left'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['backward', 'right'], ['forward', 'left'], ['forward', 'left'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['forward', 'right'], ['backward', 'left'], ['forward', 'left'], ['backward', 'right'], ['backward', 'left'], ['forward', 'right'], ['backward', 'right'], ['forward', 'left'], ['backward', 'left'], ['forward', 'right'], ['forward', 'left'], ['backward', 'right'], ['forward', 'right'], ['backward', 'left']]

# %%
x0 = np.array(x)

# %%
x == x0
# Out:
# array([[ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True],
# ...

# %%
np.array_equal(x, x0)
# Out:
# True
